# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
df = pd.read_csv(r'C:\Downloads\1976-2016-president.csv')

# %%
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# ...

# %%
ohio_crime = pd.read_csv(r'C:\Documents\Ohio\ohio-violent-crime.csv')

# %%
ohio_crime.groupby(["Year", "Rate"]).sort
print(ohio_crime)
# Out:
#     Year   Rate       Location
# 0   2015  373.7  United States
# 1   1985  558.1  United States
# 2   2000  506.5  United States
# 3   1997  611.0  United States
# 4   1998  567.6  United States
# ..   ...    ...            ...
# 65  1994  485.8           Ohio
# 66  2017  296.8           Ohio
# 67  2016  307.7           Ohio
# 68  2018  294.8           Ohio
# 69  2019  293.2           Ohio
#
# [70 rows x 3 columns]

# %%
Ohio_manufacturing = pd.read_csv(r'C:\Documents\Ohio\OHMFG.csv', parse_dates=True)

# %%
Ohio_manufacturing
# Out:
#            DATE   OHMFG
# 0    1990-01-01  1044.2
# 1    1990-02-01  1061.5
# 2    1990-03-01  1064.7
# 3    1990-04-01  1068.8
# 4    1990-05-01  1068.4
# ..          ...     ...
# 363  2020-04-01   602.9
# 364  2020-05-01   629.0
# 365  2020-06-01   659.1
# 366  2020-07-01   656.1
# 367  2020-08-01   660.6
#
# [368 rows x 2 columns]

# %%
Ohio_manufacturing = Ohio_manufacturing.set_index('DATE')

# %%
Ohio_manufacturing.plot(grid=True, figsize=(15,10))
plt.ylabel('Manufacturing Employees')
plt.title('Ohio Total Employees: Manufacturing (Thousands of Persons)')
# Out:
# Text(0.5, 1.0, 'Ohio Total Employees: Manufacturing (Thousands of Persons)')

# %%
def voting_graph(x=''):
    state_name = df[df['state']==x]
    rep = state_name[state_name['party']=='republican']
    dem = state_name[state_name['party']=='democrat']
    plt.figure(figsize=(15,7))
    plt.plot(rep.year, rep.candidatevotes, label='Republican',color='red')
    plt.plot(dem.year, dem.candidatevotes, label='Democrat', color='blue')
    plt.title('Republican vs. Democrat')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
voting_graph('Ohio')

# %%
ohio_unemployment = pd.read_csv(r'C:\Users\spyle\Documents\Ohio\OHUR.csv')

# %%
ohio_unemployment = ohio_unemployment.set_index('DATE')

# %%
ohio_unemployment.plot(grid=True, figsize=(15,10))
